# %%
import requests
import pandas as pd 
from yahoo_fin import stock_info as si 
from pandas_datareader import DataReader
import numpy as np

# %%
tickers = si.tickers_sp500()
recommendations = []

for ticker in tickers:
    lhs_url = 'https://query2.finance.yahoo.com/v10/finance/quoteSummary/'
    rhs_url = '?formatted=true&crumb=swg7qs5y9UP&lang=en-US&region=US&' \
              'modules=upgradeDowngradeHistory,recommendationTrend,' \
              'financialData,earningsHistory,earningsTrend,industryTrend&' \
              'corsDomain=finance.yahoo.com'
    
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
    url =  lhs_url + ticker + rhs_url
    r = requests.get(url, headers=headers)
    if not r.ok:
        recommendation = 6
    try:
        result = r.json()['quoteSummary']['result'][0]
        recommendation =result['financialData']['recommendationMean']['fmt']
    except:
        recommendation = 6
    
    recommendations.append(recommendation)
    
    print("--------------------------------------------")
    print ("{} has an average recommendation of: ".format(ticker), recommendation)
    #time.sleep(0.5)
    
dataframe = pd.DataFrame(list(zip(tickers, recommendations)), columns =['Company', 'Recommendations']) 
dataframe = dataframe.set_index('Company')
dataframe.to_csv('recommendations.csv')

print (dataframe)
# Out:
# --------------------------------------------
# A has an average recommendation of:  3.00
# --------------------------------------------
# AAL has an average recommendation of:  3.00
# --------------------------------------------
# AAP has an average recommendation of:  2.20
# --------------------------------------------
# AAPL has an average recommendation of:  1.90
# --------------------------------------------
# ABBV has an average recommendation of:  2.20
# --------------------------------------------
# ABC has an average recommendation of:  2.10
# --------------------------------------------
# ABMD has an average recommendation of:  2.60
# --------------------------------------------
# ABT has an average recommendation of:  2.10
# --------------------------------------------
# ACN has an average recommendation of:  2.00
# --------------------------------------------
# ADBE has an average recommendation of:  2.20
# --------------------------------------------
# ADI has an average recommendation of:  1.90
# --------------------------------------------
# ADM has an average recommendation of:  2.30
# --------------------------------------------
# ADP has an average recommendation of:  3.00
# --------------------------------------------
# ADSK has an average recommendation of:  2.10
# --------------------------------------------
# AEE has an average recommendation of:  2.10
# --------------------------------------------
# AEP has an average recommendation of:  2.20
# --------------------------------------------
# AES has an average recommendation of:  1.80
# --------------------------------------------
# AFL has an average recommendation of:  2.90
# --------------------------------------------
# AIG has an average recommendation of:  2.20
# --------------------------------------------
# AIZ has an average recommendation of:  1.80
# --------------------------------------------
# AJG has an average recommendation of:  2.10
# --------------------------------------------
# AKAM has an average recommendation of:  2.50
# --------------------------------------------
# ALB has an average recommendation of:  2.40
# --------------------------------------------
# ALGN has an average recommendation of:  2.20
# --------------------------------------------
# ALK has an average recommendation of:  1.90
# --------------------------------------------
# ALL has an average recommendation of:  2.40
# --------------------------------------------
# ALLE has an average recommendation of:  2.60
# --------------------------------------------
# AMAT has an average recommendation of:  2.00
# --------------------------------------------
# AMCR has an average recommendation of:  2.80
# --------------------------------------------
# AMD has an average recommendation of:  2.00
# --------------------------------------------
# AME has an average recommendation of:  2.20
# --------------------------------------------
# AMGN has an average recommendation of:  2.60
# --------------------------------------------
# AMP has an average recommendation of:  2.10
# --------------------------------------------
# AMT has an average recommendation of:  2.00
# --------------------------------------------
# AMZN has an average recommendation of:  1.80
# --------------------------------------------
# ANET has an average recommendation of:  2.30
# --------------------------------------------
# ANSS has an average recommendation of:  2.40
# --------------------------------------------
# AON has an average recommendation of:  2.90
# --------------------------------------------
# AOS has an average recommendation of:  2.70
# --------------------------------------------
# APA has an average recommendation of:  2.20
# --------------------------------------------
# APD has an average recommendation of:  2.30
# --------------------------------------------
# APH has an average recommendation of:  2.10
# --------------------------------------------
# APTV has an average recommendation of:  2.10
# --------------------------------------------
# ARE has an average recommendation of:  1.70
# --------------------------------------------
# ATO has an average recommendation of:  2.40
# --------------------------------------------
# ATVI has an average recommendation of:  2.30
# --------------------------------------------
# AVB has an average recommendation of:  2.50
# --------------------------------------------
# AVGO has an average recommendation of:  1.90
# --------------------------------------------
# AVY has an average recommendation of:  2.10
# --------------------------------------------
# AWK has an average recommendation of:  2.60
# --------------------------------------------
# AXP has an average recommendation of:  2.40
# --------------------------------------------
# AZO has an average recommendation of:  2.10
# --------------------------------------------
# BA has an average recommendation of:  6
# --------------------------------------------
# BAC has an average recommendation of:  2.20
# --------------------------------------------
# BALL has an average recommendation of:  2.70
# --------------------------------------------
# BAX has an average recommendation of:  2.20
# --------------------------------------------
# BBWI has an average recommendation of:  6
# --------------------------------------------
# BBY has an average recommendation of:  2.80
# --------------------------------------------
# BDX has an average recommendation of:  2.40
# --------------------------------------------
# BEN has an average recommendation of:  3.40
# --------------------------------------------
# BF-B has an average recommendation of:  3.10
# --------------------------------------------
# BIIB has an average recommendation of:  2.20
# --------------------------------------------
# BIO has an average recommendation of:  1.60
# --------------------------------------------
# BK has an average recommendation of:  2.40
# --------------------------------------------
# BKNG has an average recommendation of:  2.20
# --------------------------------------------
# BKR has an average recommendation of:  2.00
# --------------------------------------------
# BLK has an average recommendation of:  2.00
# --------------------------------------------
# BMY has an average recommendation of:  2.30
# --------------------------------------------
# BR has an average recommendation of:  2.80
# --------------------------------------------
# BRK-B has an average recommendation of:  2.80
# --------------------------------------------
# BRO has an average recommendation of:  2.60
# --------------------------------------------
# BSX has an average recommendation of:  1.70
# --------------------------------------------
# BWA has an average recommendation of:  2.40
# --------------------------------------------
# BXP has an average recommendation of:  2.30
# --------------------------------------------
# C has an average recommendation of:  2.50
# --------------------------------------------
# CAG has an average recommendation of:  2.70
# --------------------------------------------
# CAH has an average recommendation of:  2.80
# --------------------------------------------
# CARR has an average recommendation of:  2.40
# --------------------------------------------
# CAT has an average recommendation of:  3.00
# --------------------------------------------
# CB has an average recommendation of:  6
# --------------------------------------------
# CBOE has an average recommendation of:  2.40
# --------------------------------------------
# CBRE has an average recommendation of:  1.90
# --------------------------------------------
# CCI has an average recommendation of:  2.40
# --------------------------------------------
# CCL has an average recommendation of:  2.00
# --------------------------------------------
# CDAY has an average recommendation of:  6
# --------------------------------------------
# CDNS has an average recommendation of:  2.10
# --------------------------------------------
# CDW has an average recommendation of:  1.80
# --------------------------------------------
# CE has an average recommendation of:  2.60
# --------------------------------------------
# CEG has an average recommendation of:  1.90
# --------------------------------------------
# CF has an average recommendation of:  2.40
# --------------------------------------------
# CFG has an average recommendation of:  2.00
# --------------------------------------------
# CHD has an average recommendation of:  3.00
# --------------------------------------------
# CHRW has an average recommendation of:  2.90
# --------------------------------------------
# CHTR has an average recommendation of:  2.60
# --------------------------------------------
# CI has an average recommendation of:  2.20
# --------------------------------------------
# CINF has an average recommendation of:  2.90
# --------------------------------------------
# CL has an average recommendation of:  2.70
# --------------------------------------------
# CLX has an average recommendation of:  3.40
# --------------------------------------------
# CMA has an average recommendation of:  2.20
# --------------------------------------------
# CMCSA has an average recommendation of:  2.40
# --------------------------------------------
# CME has an average recommendation of:  2.40
# --------------------------------------------
# CMG has an average recommendation of:  1.80
# --------------------------------------------
# CMI has an average recommendation of:  2.40
# --------------------------------------------
# CMS has an average recommendation of:  2.50
# --------------------------------------------
# CNC has an average recommendation of:  1.90
# --------------------------------------------
# CNP has an average recommendation of:  1.90
# --------------------------------------------
# COF has an average recommendation of:  2.30
# --------------------------------------------
# COO has an average recommendation of:  2.50
# --------------------------------------------
# COP has an average recommendation of:  1.90
# --------------------------------------------
# COST has an average recommendation of:  2.10
# --------------------------------------------
# CPB has an average recommendation of:  3.30
# --------------------------------------------
# CPRT has an average recommendation of:  1.60
# --------------------------------------------
# CPT has an average recommendation of:  2.10
# --------------------------------------------
# CRL has an average recommendation of:  1.70
# --------------------------------------------
# CRM has an average recommendation of:  1.90
# --------------------------------------------
# CSCO has an average recommendation of:  2.50
# --------------------------------------------
# CSGP has an average recommendation of:  1.80
# --------------------------------------------
# CSX has an average recommendation of:  2.20
# --------------------------------------------
# CTAS has an average recommendation of:  2.20
# --------------------------------------------
# CTLT has an average recommendation of:  1.70
# --------------------------------------------
# CTRA has an average recommendation of:  2.50
# --------------------------------------------
# CTSH has an average recommendation of:  2.60
# --------------------------------------------
# CTVA has an average recommendation of:  2.20
# --------------------------------------------
# CVS has an average recommendation of:  2.10
# --------------------------------------------
# CVX has an average recommendation of:  2.30
# --------------------------------------------
# CZR has an average recommendation of:  1.90
# --------------------------------------------
# D has an average recommendation of:  2.30
# --------------------------------------------
# DAL has an average recommendation of:  1.80
# --------------------------------------------
# DD has an average recommendation of:  2.20
# --------------------------------------------
# DE has an average recommendation of:  2.10
# --------------------------------------------
# DFS has an average recommendation of:  2.30
# --------------------------------------------
# DG has an average recommendation of:  2.10
# --------------------------------------------
# DGX has an average recommendation of:  2.50
# --------------------------------------------
# DHI has an average recommendation of:  2.00
# --------------------------------------------
# DHR has an average recommendation of:  1.80
# --------------------------------------------
# DIS has an average recommendation of:  2.00
# --------------------------------------------
# DISH has an average recommendation of:  2.20
# --------------------------------------------
# DLR has an average recommendation of:  2.10
# --------------------------------------------
# DLTR has an average recommendation of:  2.40
# --------------------------------------------
# DOV has an average recommendation of:  2.20
# --------------------------------------------
# DOW has an average recommendation of:  2.90
# --------------------------------------------
# DPZ has an average recommendation of:  2.50
# --------------------------------------------
# DRI has an average recommendation of:  2.00
# --------------------------------------------
# DTE has an average recommendation of:  2.20
# --------------------------------------------
# DUK has an average recommendation of:  2.50
# --------------------------------------------
# DVA has an average recommendation of:  3.00
# --------------------------------------------
# DVN has an average recommendation of:  2.20
# --------------------------------------------
# DXC has an average recommendation of:  2.70
# --------------------------------------------
# DXCM has an average recommendation of:  1.60
# --------------------------------------------
# EA has an average recommendation of:  2.00
# --------------------------------------------
# EBAY has an average recommendation of:  2.60
# --------------------------------------------
# ECL has an average recommendation of:  2.50
# --------------------------------------------
# ED has an average recommendation of:  3.40
# --------------------------------------------
# EFX has an average recommendation of:  2.20
# --------------------------------------------
# EIX has an average recommendation of:  2.40
# --------------------------------------------
# EL has an average recommendation of:  2.00
# --------------------------------------------
# ELV has an average recommendation of:  1.80
# --------------------------------------------
# EMN has an average recommendation of:  2.50
# --------------------------------------------
# EMR has an average recommendation of:  2.20
# --------------------------------------------
# ENPH has an average recommendation of:  2.10
# --------------------------------------------
# EOG has an average recommendation of:  2.00
# --------------------------------------------
# EPAM has an average recommendation of:  1.70
# --------------------------------------------
# EQIX has an average recommendation of:  2.00
# --------------------------------------------
# EQR has an average recommendation of:  2.60
# --------------------------------------------
# EQT has an average recommendation of:  1.90
# --------------------------------------------
# ES has an average recommendation of:  2.40
# --------------------------------------------
# ESS has an average recommendation of:  2.40
# --------------------------------------------
# ETN has an average recommendation of:  2.10
# --------------------------------------------
# ETR has an average recommendation of:  2.10
# --------------------------------------------
# ETSY has an average recommendation of:  2.30
# --------------------------------------------
# EVRG has an average recommendation of:  2.40
# --------------------------------------------
# EW has an average recommendation of:  2.00
# --------------------------------------------
# EXC has an average recommendation of:  2.10
# --------------------------------------------
# EXPD has an average recommendation of:  3.10
# --------------------------------------------
# EXPE has an average recommendation of:  2.40
# --------------------------------------------
# EXR has an average recommendation of:  2.30
# --------------------------------------------
# F has an average recommendation of:  2.70
# --------------------------------------------
# FANG has an average recommendation of:  1.90
# --------------------------------------------
# FAST has an average recommendation of:  3.00
# --------------------------------------------
# FBHS has an average recommendation of:  2.40
# --------------------------------------------
# FCX has an average recommendation of:  2.40
# --------------------------------------------
# FDS has an average recommendation of:  3.00
# --------------------------------------------
# FDX has an average recommendation of:  2.30
# --------------------------------------------
# FE has an average recommendation of:  2.50
# --------------------------------------------
# FFIV has an average recommendation of:  2.70
# --------------------------------------------
# FIS has an average recommendation of:  2.00
# --------------------------------------------
# FISV has an average recommendation of:  2.10
# --------------------------------------------
# FITB has an average recommendation of:  2.00
# --------------------------------------------
# FLT has an average recommendation of:  2.20
# --------------------------------------------
# FMC has an average recommendation of:  2.30
# --------------------------------------------
# FOX has an average recommendation of:  6
# --------------------------------------------
# FOXA has an average recommendation of:  2.40
# --------------------------------------------
# FRC has an average recommendation of:  2.30
# --------------------------------------------
# FRT has an average recommendation of:  2.30
# --------------------------------------------
# FTNT has an average recommendation of:  1.90
# --------------------------------------------
# FTV has an average recommendation of:  2.10
# --------------------------------------------
# GD has an average recommendation of:  2.10
# --------------------------------------------
# GE has an average recommendation of:  2.00
# --------------------------------------------
# GILD has an average recommendation of:  2.50
# --------------------------------------------
# GIS has an average recommendation of:  3.10
# --------------------------------------------
# GL has an average recommendation of:  2.50
# --------------------------------------------
# GLW has an average recommendation of:  2.10
# --------------------------------------------
# GM has an average recommendation of:  2.10
# --------------------------------------------
# GNRC has an average recommendation of:  1.70
# --------------------------------------------
# GOOG has an average recommendation of:  1.50
# --------------------------------------------
# GOOGL has an average recommendation of:  1.80
# --------------------------------------------
# GPC has an average recommendation of:  2.80
# --------------------------------------------
# GPN has an average recommendation of:  1.80
# --------------------------------------------
# GRMN has an average recommendation of:  6
# --------------------------------------------
# GS has an average recommendation of:  2.30
# --------------------------------------------
# GWW has an average recommendation of:  2.40
# --------------------------------------------
# HAL has an average recommendation of:  2.10
# --------------------------------------------
# HAS has an average recommendation of:  1.80
# --------------------------------------------
# HBAN has an average recommendation of:  2.60
# --------------------------------------------
# HCA has an average recommendation of:  1.80
# --------------------------------------------
# HD has an average recommendation of:  2.10
# --------------------------------------------
# HES has an average recommendation of:  2.30
# --------------------------------------------
# HIG has an average recommendation of:  2.00
# --------------------------------------------
# HII has an average recommendation of:  2.70
# --------------------------------------------
# HLT has an average recommendation of:  2.20
# --------------------------------------------
# HOLX has an average recommendation of:  2.30
# --------------------------------------------
# HON has an average recommendation of:  2.30
# --------------------------------------------
# HPE has an average recommendation of:  2.50
# --------------------------------------------
# HPQ has an average recommendation of:  3.10
# --------------------------------------------
# HRL has an average recommendation of:  3.00
# --------------------------------------------
# HSIC has an average recommendation of:  2.90
# --------------------------------------------
# HST has an average recommendation of:  2.10
# --------------------------------------------
# HSY has an average recommendation of:  2.50
# --------------------------------------------
# HUM has an average recommendation of:  2.00
# --------------------------------------------
# HWM has an average recommendation of:  1.90
# --------------------------------------------
# IBM has an average recommendation of:  2.40
# --------------------------------------------
# ICE has an average recommendation of:  2.10
# --------------------------------------------
# IDXX has an average recommendation of:  2.30
# --------------------------------------------
# IEX has an average recommendation of:  2.20
# --------------------------------------------
# IFF has an average recommendation of:  1.50
# --------------------------------------------
# ILMN has an average recommendation of:  2.50
# --------------------------------------------
# INCY has an average recommendation of:  2.30
# --------------------------------------------
# INTC has an average recommendation of:  3.20
# --------------------------------------------
# INTU has an average recommendation of:  1.90
# --------------------------------------------
# INVH has an average recommendation of:  1.90
# --------------------------------------------
# IP has an average recommendation of:  3.10
# --------------------------------------------
# IPG has an average recommendation of:  2.40
# --------------------------------------------
# IQV has an average recommendation of:  1.60
# --------------------------------------------
# IR has an average recommendation of:  2.20
# --------------------------------------------
# IRM has an average recommendation of:  2.10
# --------------------------------------------
# ISRG has an average recommendation of:  2.20
# --------------------------------------------
# IT has an average recommendation of:  2.10
# --------------------------------------------
# ITW has an average recommendation of:  3.00
# --------------------------------------------
# IVZ has an average recommendation of:  6
# --------------------------------------------
# J has an average recommendation of:  1.70
# --------------------------------------------
# JBHT has an average recommendation of:  2.10
# --------------------------------------------
# JCI has an average recommendation of:  6
# --------------------------------------------
# JKHY has an average recommendation of:  2.80
# --------------------------------------------
# JNJ has an average recommendation of:  2.40
# --------------------------------------------
# JNPR has an average recommendation of:  2.80
# --------------------------------------------
# JPM has an average recommendation of:  2.30
# --------------------------------------------
# K has an average recommendation of:  3.10
# --------------------------------------------
# KDP has an average recommendation of:  2.30
# --------------------------------------------
# KEY has an average recommendation of:  2.70
# --------------------------------------------
# KEYS has an average recommendation of:  2.00
# --------------------------------------------
# KHC has an average recommendation of:  2.60
# --------------------------------------------
# KIM has an average recommendation of:  2.10
# --------------------------------------------
# KLAC has an average recommendation of:  2.00
# --------------------------------------------
# KMB has an average recommendation of:  3.20
# --------------------------------------------
# KMI has an average recommendation of:  2.90
# --------------------------------------------
# KMX has an average recommendation of:  2.30
# --------------------------------------------
# KO has an average recommendation of:  2.10
# --------------------------------------------
# KR has an average recommendation of:  2.80
# --------------------------------------------
# L has an average recommendation of:  3.00
# --------------------------------------------
# LDOS has an average recommendation of:  2.10
# --------------------------------------------
# LEN has an average recommendation of:  2.30
# --------------------------------------------
# LH has an average recommendation of:  1.90
# --------------------------------------------
# LHX has an average recommendation of:  6
# --------------------------------------------
# LIN has an average recommendation of:  1.80
# --------------------------------------------
# LKQ has an average recommendation of:  1.70
# --------------------------------------------
# LLY has an average recommendation of:  2.00
# --------------------------------------------
# LMT has an average recommendation of:  2.70
# --------------------------------------------
# LNC has an average recommendation of:  2.70
# --------------------------------------------
# LNT has an average recommendation of:  2.50
# --------------------------------------------
# LOW has an average recommendation of:  2.10
# --------------------------------------------
# LRCX has an average recommendation of:  2.20
# --------------------------------------------
# LUMN has an average recommendation of:  3.50
# --------------------------------------------
# LUV has an average recommendation of:  2.00
# --------------------------------------------
# LVS has an average recommendation of:  2.10
# --------------------------------------------
# LW has an average recommendation of:  1.90
# --------------------------------------------
# LYB has an average recommendation of:  2.80
# --------------------------------------------
# LYV has an average recommendation of:  2.10
# --------------------------------------------
# MA has an average recommendation of:  1.80
# --------------------------------------------
# MAA has an average recommendation of:  2.40
# --------------------------------------------
# MAR has an average recommendation of:  2.40
# --------------------------------------------
# MAS has an average recommendation of:  2.50
# --------------------------------------------
# MCD has an average recommendation of:  2.00
# --------------------------------------------
# MCHP has an average recommendation of:  2.10
# --------------------------------------------
# MCK has an average recommendation of:  1.90
# --------------------------------------------
# MCO has an average recommendation of:  2.30
# --------------------------------------------
# MDLZ has an average recommendation of:  1.90
# --------------------------------------------
# MDT has an average recommendation of:  2.30
# --------------------------------------------
# MET has an average recommendation of:  1.80
# --------------------------------------------
# META has an average recommendation of:  2.10
# --------------------------------------------
# MGM has an average recommendation of:  2.20
# --------------------------------------------
# MHK has an average recommendation of:  3.10
# --------------------------------------------
# MKC has an average recommendation of:  3.00
# --------------------------------------------
# MKTX has an average recommendation of:  2.90
# --------------------------------------------
# MLM has an average recommendation of:  2.10
# --------------------------------------------
# MMC has an average recommendation of:  2.60
# --------------------------------------------
# MMM has an average recommendation of:  3.30
# --------------------------------------------
# MNST has an average recommendation of:  2.30
# --------------------------------------------
# MO has an average recommendation of:  2.70
# --------------------------------------------
# MOH has an average recommendation of:  2.60
# --------------------------------------------
# MOS has an average recommendation of:  2.50
# --------------------------------------------
# MPC has an average recommendation of:  1.90
# --------------------------------------------
# MPWR has an average recommendation of:  1.80
# --------------------------------------------
# MRK has an average recommendation of:  2.20
# --------------------------------------------
# MRNA has an average recommendation of:  2.50
# --------------------------------------------
# MRO has an average recommendation of:  2.40
# --------------------------------------------
# MS has an average recommendation of:  6
# --------------------------------------------
# MSCI has an average recommendation of:  2.40
# --------------------------------------------
# MSFT has an average recommendation of:  1.70
# --------------------------------------------
# MSI has an average recommendation of:  2.00
# --------------------------------------------
# MTB has an average recommendation of:  2.30
# --------------------------------------------
# MTCH has an average recommendation of:  2.10
# --------------------------------------------
# MTD has an average recommendation of:  2.80
# --------------------------------------------
# MU has an average recommendation of:  2.20
# --------------------------------------------
# NCLH has an average recommendation of:  2.30
# --------------------------------------------
# NDAQ has an average recommendation of:  2.10
# --------------------------------------------
# NDSN has an average recommendation of:  2.30
# --------------------------------------------
# NEE has an average recommendation of:  1.90
# --------------------------------------------
# NEM has an average recommendation of:  2.00
# --------------------------------------------
# NFLX has an average recommendation of:  2.70
# --------------------------------------------
# NI has an average recommendation of:  2.00
# --------------------------------------------
# NKE has an average recommendation of:  2.20
# --------------------------------------------
# NLOK has an average recommendation of:  2.40
# --------------------------------------------
# NOC has an average recommendation of:  2.20
# --------------------------------------------
# NOW has an average recommendation of:  1.80
# --------------------------------------------
# NRG has an average recommendation of:  2.60
# --------------------------------------------
# NSC has an average recommendation of:  2.50
# --------------------------------------------
# NTAP has an average recommendation of:  2.40
# --------------------------------------------
# NTRS has an average recommendation of:  2.60
# --------------------------------------------
# NUE has an average recommendation of:  2.90
# --------------------------------------------
# NVDA has an average recommendation of:  2.10
# --------------------------------------------
# NVR has an average recommendation of:  2.70
# --------------------------------------------
# NWL has an average recommendation of:  2.40
# --------------------------------------------
# NWS has an average recommendation of:  6
# --------------------------------------------
# NWSA has an average recommendation of:  2.00
# --------------------------------------------
# NXPI has an average recommendation of:  2.20
# --------------------------------------------
# O has an average recommendation of:  2.40
# --------------------------------------------
# ODFL has an average recommendation of:  2.80
# --------------------------------------------
# OGN has an average recommendation of:  2.60
# --------------------------------------------
# OKE has an average recommendation of:  2.60
# --------------------------------------------
# OMC has an average recommendation of:  2.60
# --------------------------------------------
# ON has an average recommendation of:  2.10
# --------------------------------------------
# ORCL has an average recommendation of:  2.70
# --------------------------------------------
# ORLY has an average recommendation of:  2.10
# --------------------------------------------
# OTIS has an average recommendation of:  2.40
# --------------------------------------------
# OXY has an average recommendation of:  2.70
# --------------------------------------------
# PARA has an average recommendation of:  3.00
# --------------------------------------------
# PAYC has an average recommendation of:  2.00
# --------------------------------------------
# PAYX has an average recommendation of:  2.90
# --------------------------------------------
# PCAR has an average recommendation of:  2.50
# --------------------------------------------
# PCG has an average recommendation of:  2.00
# --------------------------------------------
# PEAK has an average recommendation of:  2.20
# --------------------------------------------
# PEG has an average recommendation of:  2.10
# --------------------------------------------
# PEP has an average recommendation of:  2.50
# --------------------------------------------
# PFE has an average recommendation of:  6
# --------------------------------------------
# PFG has an average recommendation of:  3.20
# --------------------------------------------
# PG has an average recommendation of:  2.40
# --------------------------------------------
# PGR has an average recommendation of:  2.90
# --------------------------------------------
# PH has an average recommendation of:  2.00
# --------------------------------------------
# PHM has an average recommendation of:  2.40
# --------------------------------------------
# PKG has an average recommendation of:  2.70
# --------------------------------------------
# PKI has an average recommendation of:  2.70
# --------------------------------------------
# PLD has an average recommendation of:  1.80
# --------------------------------------------
# PM has an average recommendation of:  2.40
# --------------------------------------------
# PNC has an average recommendation of:  2.50
# --------------------------------------------
# PNR has an average recommendation of:  2.70
# --------------------------------------------
# PNW has an average recommendation of:  3.50
# --------------------------------------------
# POOL has an average recommendation of:  2.30
# --------------------------------------------
# PPG has an average recommendation of:  2.40
# --------------------------------------------
# PPL has an average recommendation of:  2.10
# --------------------------------------------
# PRU has an average recommendation of:  2.90
# --------------------------------------------
# PSA has an average recommendation of:  2.00
# --------------------------------------------
# PSX has an average recommendation of:  2.20
# --------------------------------------------
# PTC has an average recommendation of:  1.90
# --------------------------------------------
# PWR has an average recommendation of:  1.80
# --------------------------------------------
# PXD has an average recommendation of:  2.30
# --------------------------------------------
# PYPL has an average recommendation of:  2.10
# --------------------------------------------
# QCOM has an average recommendation of:  2.10
# --------------------------------------------
# QRVO has an average recommendation of:  2.70
