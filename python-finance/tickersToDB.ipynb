# %%
import sqlalchemy
import pandas as pd
import yfinance as yf

# %%
wiki = "https://en.wikipedia.org/wiki/"

# %%
tickersSensex = pd.read_html(wiki+'BSE_SENSEX')[1].Symbol.to_list()
tickersDOW = pd.read_html(wiki+'Dow_Jones_Industrial_Average')[1].Symbol.to_list()

# %%
tickersSensex
# Out:
# ['ASIANPAINT.BO',
#  'AXISBANK.BO',
#  'BAJAJ-AUTO.BO',
#  'BAJFINANCE.BO',
#  'BAJAJFINSV.BO',
#  'BHARTIARTL.BO',
#  'DRREDDY.BO',
#  'HCLTECH.BO',
#  'JSWSTEEL.BO',
#  'HDFCBANK.BO',
#  'HINDUNILVR.BO',
#  'ICICIBANK.BO',
#  'INDUSINDBK.BO',
#  'INFY.BO',
#  'ITC.BO',
#  'KOTAKBANK.BO',
#  'LT.BO',
#  'M&M.BO',
#  'MARUTI.BO',
#  'NESTLEIND.BO',
#  'NTPC.BO',
#  'ONGC.BO',
#  'POWERGRID.BO',
#  'RELIANCE.BO',
#  'SBIN.BO',
#  'SUNPHARMA.BO',
#  'TCS.BO',
#  'TECHM.BO',
#  'TITAN.BO',
#  'ULTRACEMCO.BO']

# %%
tickersDOW
# Out:
# ['MMM',
#  'AXP',
#  'AMGN',
#  'AAPL',
#  'BA',
#  'CAT',
#  'CVX',
#  'CSCO',
#  'KO',
#  'DIS',
#  'DOW',
#  'GS',
#  'HD',
#  'HON',
#  'IBM',
#  'INTC',
#  'JNJ',
#  'JPM',
#  'MCD',
#  'MRK',
#  'MSFT',
#  'NKE',
#  'PG',
#  'CRM',
#  'TRV',
#  'UNH',
#  'VZ',
#  'V',
#  'WBA',
#  'WMT']

# %%
def getdata(tickers):
    data = []
    for ticker in tickers:
        data.append(yf.download(ticker).reset_index())
    return data

# %%
india, US = getdata(tickersSensex),getdata(tickersDOW)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
india[0]
# Out:
#            Date         Open         High          Low        Close  \
# 0    2000-01-03    27.066631    27.066631    27.066631    27.066631
# 1    2000-01-04    27.066631    27.066631    27.066631    27.066631
# 2    2000-01-05    27.066631    27.066631    27.066631    27.066631
# 3    2000-01-06    27.066631    27.066631    27.066631    27.066631
# 4    2000-01-07    27.066631    27.066631    27.066631    27.066631
# ...         ...          ...          ...          ...          ...
# 5858 2023-07-19  3513.500000  3529.000000  3481.449951  3516.800049
# 5859 2023-07-20  3501.050049  3534.300049  3494.899902  3523.699951
# 5860 2023-07-21  3523.750000  3537.600098  3505.500000  3516.850098
# 5861 2023-07-24  3500.050049  3566.899902  3500.000000  3542.100098
# 5862 2023-07-25  3554.750000  3554.750000  3351.000000  3400.100098
#
#         Adj Close  Volume
# 0        1.049971       0
# 1        1.049971       0
# 2        1.049971       0
# 3        1.049971       0
# 4        1.049971       0
# ...           ...     ...
# 5858  3516.800049   17683
# 5859  3523.699951   33312
# 5860  3516.850098   23509
# 5861  3542.100098   19080
# 5862  3400.100098  209771
#
# [5863 rows x 7 columns]

# %%
US[0]
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1962-01-02    0.000000    4.250000    4.125000    4.156250    0.724556
# 1     1962-01-03    0.000000    4.187500    4.085938    4.187500    0.730004
# 2     1962-01-04    0.000000    4.257813    4.187500    4.187500    0.730004
# 3     1962-01-05    0.000000    4.171875    4.062500    4.078125    0.710936
# 4     1962-01-08    0.000000    4.085938    4.031250    4.054688    0.706851
# ...          ...         ...         ...         ...         ...         ...
# 15491 2023-07-19  102.849998  103.760002  102.599998  103.480003  103.480003
# 15492 2023-07-20  103.169998  104.730003  102.510002  104.290001  104.290001
# 15493 2023-07-21  104.169998  104.540001  103.220001  104.330002  104.330002
# 15494 2023-07-24  104.529999  105.599998  103.980003  104.269997  104.269997
# 15495 2023-07-25  107.550003  110.849998  107.009201  109.839996  109.839996
#
#         Volume
# 0       212800
# 1       422400
# 2       212800
# 3       315200
# 4       334400
# ...        ...
# 15491  2088900
# 15492  2866300
# 15493  2498700
# 15494  3328300
# 15495  5162474
#
# [15496 rows x 7 columns]

# %%
len(US)
# Out:
# 30

# %%
def createengine(name):
    engine = sqlalchemy.create_engine("sqlite:///"+name)
    return engine

# %%
indiaengine,USengine = createengine("India"),createengine("USA")

# %%
def TOSQL(frames,symbols,engine):
    for frame,symbol in zip(frames,symbols):
        frame.to_sql(symbol,engine, index=False)
    print("S import")

# %%
TOSQL(india,tickersSensex, indiaengine)
# Out:
# S import

# %%
TOSQL(US,tickersDOW, USengine)
# Out:
# S import
