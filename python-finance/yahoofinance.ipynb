# %%
import yfinance as yf

# %%
stock = yf.Ticker("AAPL")
hist = stock.history(period="3mo")

# %%
hist
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-05-01 00:00:00-04:00  169.046174  170.214556  168.407059  169.355743
# 2023-05-02 00:00:00-04:00  169.855052  170.114703  167.308571  168.307190
# 2023-05-03 00:00:00-04:00  169.265876  170.683912  166.929111  167.218704
# 2023-05-04 00:00:00-04:00  164.662239  166.809263  164.083038  165.560989
# 2023-05-05 00:00:00-04:00  170.743827  174.059249  170.524130  173.330261
# ...                               ...         ...         ...         ...
# 2023-07-26 00:00:00-04:00  193.669998  195.639999  193.320007  194.500000
# 2023-07-27 00:00:00-04:00  196.020004  197.199997  192.550003  193.220001
# 2023-07-28 00:00:00-04:00  194.669998  196.630005  194.139999  195.830002
# 2023-07-31 00:00:00-04:00  196.059998  196.490005  195.259995  196.449997
# 2023-08-01 00:00:00-04:00  196.235001  196.729996  195.279999  195.895004
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
son_kapanis_fiyati = hist['Close'].iloc[-1]

print("Hissenin Son Kapanış Fiyatı:", son_kapanis_fiyati)
# Out:
# Hissenin Son Kapanış Fiyatı: 195.89500427246094

# %%
stock.dividends
# Out:
# Series([], Name: Dividends, dtype: float64)

# %%
stock.splits
# Out:
# Series([], Name: Stock Splits, dtype: float64)

# %%
stock.news
# Out:
# [{'uuid': '65b53896-faf4-3a06-9d0d-a63cf3c83192',
#   'title': 'Best Dow Jones Stocks To Buy And Watch In August 2023: Caterpillar Surges On Earnings',
#   'publisher': "Investor's Business Daily",
#   'link': 'https://finance.yahoo.com/m/65b53896-faf4-3a06-9d0d-a63cf3c83192/best-dow-jones-stocks-to-buy.html',
#   'providerPublishTime': 1690914513,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/JPX5jeyihDRi4N6ueuYJVQ--~B/aD01NjM7dz0xMDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/ed4e9880b0c3e9257977ca3554a6c383',
#      'width': 1000,
#      'height': 563,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/.0m6SEAzHJOxc1V1Vw8fuA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/ed4e9880b0c3e9257977ca3554a6c383',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['^DJI', 'MSFT', 'AAPL']},
# ...
